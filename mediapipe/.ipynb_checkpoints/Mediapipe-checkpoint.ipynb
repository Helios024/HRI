# %%
import mediapipe as mp
import cv2
import numpy as np
import uuid
import os

# %% [markdown]
# Using drawing_utils to render the hand landmark model
# <BR> Hands model:<img src=https://www.section.io/engineering-education/creating-a-hand-gesture-volume-controller-using-python-and-pycharm/hand.jpg>

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
def draw_hlandmarks(frame,results):
    for num,hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(frame,hand,mp_hands.HAND_CONNECTIONS) #rendering

# %% [markdown]
# Detection: Threshold for initial detecition to be successful
# Tracking: Threshold for Tracking after Initial Detection

# %%
vidcap = cv2.VideoCapture(2)
with mp_hands.Hands(min_detection_confidence=0.8,min_tracking_confidence=0.5,max_num_hands=1) as hands:
    while vidcap.isOpened():
        ret,frame = vidcap.read()
        image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)#OpenCV works in BlueGreenRed format but Mediapipe works in 
                                                     #RedGreenBlue format
        image.flags.writeable = False #setting flags to prevent copying the image
        results = hands.process(image) #detection
        image.flags.writeable = True #setting it back
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) #changing back
        #print(results) #output all the landmarks 
        if results.multi_hand_landmarks:
            draw_hlandmarks(frame,results)
        cv2.imshow('Hand Tracking',frame)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    vidcap.release()
    cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt
draw_hlandmarks(frame,results)
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from matplotlib import pyplot as plt
# ----> 2 draw_hlandmarks(frame,results)
#       3 plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
#
# NameError: name 'frame' is not defined

# %%
# np.save(os.path.join(DATA_PATH,action,str(sequence),str(frame_num)))

# %%
def extract_keypoints(results):
    if results.multi_hand_landmarks:
        return np.array([[lmark.x,lmark.y,lmark.z] for lmark in results.multi_hand_landmarks[0].landmark]).flatten() \
        if results.multi_hand_landmarks[0].landmark else np.zeros((21*3))
    else:
        return np.zeros((21*3))

# %%
extract_keypoints(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 extract_keypoints(results)
#
# NameError: name 'results' is not defined

# %%
pose = extract_keypoints(results)
len(pose)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pose = extract_keypoints(results)
#       2 len(pose)
#
# NameError: name 'results' is not defined

# %%
pose
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pose
#
# NameError: name 'pose' is not defined

# %%
DATA_PATH= os.path.join('Mediapipe_Data') #Path for exported data
actions = np.array(['Active','Draw']) #Detect signs
no_sequences = 30 #number videos
sequences_length = 30 #number of frames

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH,action,str(sequence)))
        except:
            pass

# %%
vidcap = cv2.VideoCapture(0)
with mp_hands.Hands(min_detection_confidence=0.8,min_tracking_confidence=0.5,max_num_hands=1) as hands:
    for action in ["Draw"]:
        for sequence in range(no_sequences):
            for frame_num in range(sequences_length):
                ret,frame = vidcap.read()
                image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)#OpenCV works in BlueGreenRed 
                                                             #format but Mediapipe works in RedGreenBlue format
                image.flags.writeable = False #setting flags to prevent copying the image
                results = hands.process(image) #detection
                image.flags.writeable = True #setting it back
                image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) #changing back
                #print(results) #output all the landmarks 
                if results.multi_hand_landmarks:
                    draw_hlandmarks(image,results) #rendering the landmarks
                if frame_num ==  0:
                    cv2.putText(image,'Start',(120,200),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),4,cv2.LINE_AA)
                    cv2.putText(image,'{} sequence {}'.format(action,sequence),(30,20),
                                cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1,cv2.LINE_AA)
                    cv2.imshow('Hand Tracking',image)
                    cv2.waitKey(2000) #two second delay between the videos
                else:
                    cv2.putText(image,'{} sequence {}'.format(action,sequence),(30,20),
                                cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1,cv2.LINE_AA)
                    cv2.imshow('Hand Tracking',image)
                
                
                keypoints = extract_keypoints(results)
                seqpath = os.path.join(DATA_PATH,action,str(sequence),str(frame_num))
                np.save(seqpath, keypoints)
                
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    vidcap.release()
    cv2.destroyAllWindows()

# %%
vidcap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
labelmap = {label:num for num,label in enumerate(actions)}

# %%
labelmap
# Out:
# {'Active': 0, 'Draw': 1}

# %%
actions
# Out:
# array(['Active', 'Draw'], dtype='<U6')

# %%
sequences,labels = [],[]
for action in actions:
    for sequence in range(no_sequences):
        windows = []
        for frame_num in range(sequences_length):
            print(os.path.join(DATA_PATH,action,str(sequence),'{}.npy'.format(frame_num)))
            res = np.load(os.path.join(DATA_PATH,action,str(sequence),'{}.npy'.format(frame_num)))
            windows.append(res)
        sequences.append(windows)
        labels.append(labelmap[action])
# Out:
# Mediapipe_Data\Active\0\0.npy
# Mediapipe_Data\Active\0\1.npy
# Mediapipe_Data\Active\0\2.npy
# Mediapipe_Data\Active\0\3.npy
# Mediapipe_Data\Active\0\4.npy
# Mediapipe_Data\Active\0\5.npy
# Mediapipe_Data\Active\0\6.npy
# Mediapipe_Data\Active\0\7.npy
# Mediapipe_Data\Active\0\8.npy
# Mediapipe_Data\Active\0\9.npy
# Mediapipe_Data\Active\0\10.npy
# Mediapipe_Data\Active\0\11.npy
# Mediapipe_Data\Active\0\12.npy
# Mediapipe_Data\Active\0\13.npy
# Mediapipe_Data\Active\0\14.npy
# Mediapipe_Data\Active\1\0.npy
# Mediapipe_Data\Active\1\1.npy
# Mediapipe_Data\Active\1\2.npy
# Mediapipe_Data\Active\1\3.npy
# Mediapipe_Data\Active\1\4.npy
# Mediapipe_Data\Active\1\5.npy
# Mediapipe_Data\Active\1\6.npy
# Mediapipe_Data\Active\1\7.npy
# Mediapipe_Data\Active\1\8.npy
# Mediapipe_Data\Active\1\9.npy
# Mediapipe_Data\Active\1\10.npy
# Mediapipe_Data\Active\1\11.npy
# Mediapipe_Data\Active\1\12.npy
# Mediapipe_Data\Active\1\13.npy
# Mediapipe_Data\Active\1\14.npy
# Mediapipe_Data\Active\2\0.npy
# Mediapipe_Data\Active\2\1.npy
# Mediapipe_Data\Active\2\2.npy
# Mediapipe_Data\Active\2\3.npy
# Mediapipe_Data\Active\2\4.npy
# Mediapipe_Data\Active\2\5.npy
# Mediapipe_Data\Active\2\6.npy
# Mediapipe_Data\Active\2\7.npy
# Mediapipe_Data\Active\2\8.npy
# Mediapipe_Data\Active\2\9.npy
# Mediapipe_Data\Active\2\10.npy
# Mediapipe_Data\Active\2\11.npy
# Mediapipe_Data\Active\2\12.npy
# Mediapipe_Data\Active\2\13.npy
# Mediapipe_Data\Active\2\14.npy
# Mediapipe_Data\Active\3\0.npy
# Mediapipe_Data\Active\3\1.npy
# Mediapipe_Data\Active\3\2.npy
# Mediapipe_Data\Active\3\3.npy
# Mediapipe_Data\Active\3\4.npy
# Mediapipe_Data\Active\3\5.npy
# Mediapipe_Data\Active\3\6.npy
# Mediapipe_Data\Active\3\7.npy
# Mediapipe_Data\Active\3\8.npy
# Mediapipe_Data\Active\3\9.npy
# Mediapipe_Data\Active\3\10.npy
# Mediapipe_Data\Active\3\11.npy
# Mediapipe_Data\Active\3\12.npy
# Mediapipe_Data\Active\3\13.npy
# Mediapipe_Data\Active\3\14.npy
# Mediapipe_Data\Active\4\0.npy
# Mediapipe_Data\Active\4\1.npy
# Mediapipe_Data\Active\4\2.npy
# Mediapipe_Data\Active\4\3.npy
# Mediapipe_Data\Active\4\4.npy
# Mediapipe_Data\Active\4\5.npy
# Mediapipe_Data\Active\4\6.npy
# Mediapipe_Data\Active\4\7.npy
# Mediapipe_Data\Active\4\8.npy
# Mediapipe_Data\Active\4\9.npy
# Mediapipe_Data\Active\4\10.npy
# Mediapipe_Data\Active\4\11.npy
# Mediapipe_Data\Active\4\12.npy
# Mediapipe_Data\Active\4\13.npy
# Mediapipe_Data\Active\4\14.npy
# Mediapipe_Data\Active\5\0.npy
# Mediapipe_Data\Active\5\1.npy
# Mediapipe_Data\Active\5\2.npy
# Mediapipe_Data\Active\5\3.npy
# Mediapipe_Data\Active\5\4.npy
# Mediapipe_Data\Active\5\5.npy
# Mediapipe_Data\Active\5\6.npy
# Mediapipe_Data\Active\5\7.npy
# Mediapipe_Data\Active\5\8.npy
# Mediapipe_Data\Active\5\9.npy
# Mediapipe_Data\Active\5\10.npy
# Mediapipe_Data\Active\5\11.npy
# Mediapipe_Data\Active\5\12.npy
# Mediapipe_Data\Active\5\13.npy
# Mediapipe_Data\Active\5\14.npy
# Mediapipe_Data\Active\6\0.npy
# Mediapipe_Data\Active\6\1.npy
# Mediapipe_Data\Active\6\2.npy
# Mediapipe_Data\Active\6\3.npy
# Mediapipe_Data\Active\6\4.npy
# Mediapipe_Data\Active\6\5.npy
# Mediapipe_Data\Active\6\6.npy
# Mediapipe_Data\Active\6\7.npy
# Mediapipe_Data\Active\6\8.npy
# Mediapipe_Data\Active\6\9.npy
# Mediapipe_Data\Active\6\10.npy
# Mediapipe_Data\Active\6\11.npy
# Mediapipe_Data\Active\6\12.npy
# Mediapipe_Data\Active\6\13.npy
# Mediapipe_Data\Active\6\14.npy
# Mediapipe_Data\Active\7\0.npy
# Mediapipe_Data\Active\7\1.npy
# Mediapipe_Data\Active\7\2.npy
# Mediapipe_Data\Active\7\3.npy
# Mediapipe_Data\Active\7\4.npy
# Mediapipe_Data\Active\7\5.npy
# Mediapipe_Data\Active\7\6.npy
# Mediapipe_Data\Active\7\7.npy
# Mediapipe_Data\Active\7\8.npy
# Mediapipe_Data\Active\7\9.npy
# Mediapipe_Data\Active\7\10.npy
# Mediapipe_Data\Active\7\11.npy
# Mediapipe_Data\Active\7\12.npy
# Mediapipe_Data\Active\7\13.npy
# Mediapipe_Data\Active\7\14.npy
# Mediapipe_Data\Active\8\0.npy
# Mediapipe_Data\Active\8\1.npy
# Mediapipe_Data\Active\8\2.npy
# Mediapipe_Data\Active\8\3.npy
# Mediapipe_Data\Active\8\4.npy
# Mediapipe_Data\Active\8\5.npy
# Mediapipe_Data\Active\8\6.npy
# Mediapipe_Data\Active\8\7.npy
# Mediapipe_Data\Active\8\8.npy
# Mediapipe_Data\Active\8\9.npy
# Mediapipe_Data\Active\8\10.npy
# Mediapipe_Data\Active\8\11.npy
# Mediapipe_Data\Active\8\12.npy
# Mediapipe_Data\Active\8\13.npy
# Mediapipe_Data\Active\8\14.npy
# Mediapipe_Data\Active\9\0.npy
# Mediapipe_Data\Active\9\1.npy
# Mediapipe_Data\Active\9\2.npy
# Mediapipe_Data\Active\9\3.npy
# Mediapipe_Data\Active\9\4.npy
# Mediapipe_Data\Active\9\5.npy
# Mediapipe_Data\Active\9\6.npy
# Mediapipe_Data\Active\9\7.npy
# Mediapipe_Data\Active\9\8.npy
# Mediapipe_Data\Active\9\9.npy
# Mediapipe_Data\Active\9\10.npy
# Mediapipe_Data\Active\9\11.npy
# Mediapipe_Data\Active\9\12.npy
# Mediapipe_Data\Active\9\13.npy
# Mediapipe_Data\Active\9\14.npy
# Mediapipe_Data\Active\10\0.npy
# Mediapipe_Data\Active\10\1.npy
# Mediapipe_Data\Active\10\2.npy
# Mediapipe_Data\Active\10\3.npy
# Mediapipe_Data\Active\10\4.npy
# Mediapipe_Data\Active\10\5.npy
# Mediapipe_Data\Active\10\6.npy
# Mediapipe_Data\Active\10\7.npy
# Mediapipe_Data\Active\10\8.npy
# Mediapipe_Data\Active\10\9.npy
# Mediapipe_Data\Active\10\10.npy
# Mediapipe_Data\Active\10\11.npy
# Mediapipe_Data\Active\10\12.npy
# Mediapipe_Data\Active\10\13.npy
# Mediapipe_Data\Active\10\14.npy
# Mediapipe_Data\Active\11\0.npy
# Mediapipe_Data\Active\11\1.npy
# Mediapipe_Data\Active\11\2.npy
# Mediapipe_Data\Active\11\3.npy
# Mediapipe_Data\Active\11\4.npy
# Mediapipe_Data\Active\11\5.npy
# Mediapipe_Data\Active\11\6.npy
# Mediapipe_Data\Active\11\7.npy
# Mediapipe_Data\Active\11\8.npy
# Mediapipe_Data\Active\11\9.npy
# Mediapipe_Data\Active\11\10.npy
# Mediapipe_Data\Active\11\11.npy
# Mediapipe_Data\Active\11\12.npy
# Mediapipe_Data\Active\11\13.npy
# Mediapipe_Data\Active\11\14.npy
# Mediapipe_Data\Active\12\0.npy
# Mediapipe_Data\Active\12\1.npy
# Mediapipe_Data\Active\12\2.npy
# Mediapipe_Data\Active\12\3.npy
# Mediapipe_Data\Active\12\4.npy
# Mediapipe_Data\Active\12\5.npy
# Mediapipe_Data\Active\12\6.npy
# Mediapipe_Data\Active\12\7.npy
# Mediapipe_Data\Active\12\8.npy
# Mediapipe_Data\Active\12\9.npy
# Mediapipe_Data\Active\12\10.npy
# Mediapipe_Data\Active\12\11.npy
# Mediapipe_Data\Active\12\12.npy
# Mediapipe_Data\Active\12\13.npy
# Mediapipe_Data\Active\12\14.npy
# Mediapipe_Data\Active\13\0.npy
# Mediapipe_Data\Active\13\1.npy
# Mediapipe_Data\Active\13\2.npy
# Mediapipe_Data\Active\13\3.npy
# Mediapipe_Data\Active\13\4.npy
# Mediapipe_Data\Active\13\5.npy
# Mediapipe_Data\Active\13\6.npy
# Mediapipe_Data\Active\13\7.npy
# Mediapipe_Data\Active\13\8.npy
# Mediapipe_Data\Active\13\9.npy
# Mediapipe_Data\Active\13\10.npy
# Mediapipe_Data\Active\13\11.npy
# Mediapipe_Data\Active\13\12.npy
# Mediapipe_Data\Active\13\13.npy
# Mediapipe_Data\Active\13\14.npy
# Mediapipe_Data\Active\14\0.npy
# Mediapipe_Data\Active\14\1.npy
# Mediapipe_Data\Active\14\2.npy
# Mediapipe_Data\Active\14\3.npy
# Mediapipe_Data\Active\14\4.npy
# Mediapipe_Data\Active\14\5.npy
# Mediapipe_Data\Active\14\6.npy
# Mediapipe_Data\Active\14\7.npy
# Mediapipe_Data\Active\14\8.npy
# Mediapipe_Data\Active\14\9.npy
# Mediapipe_Data\Active\14\10.npy
# Mediapipe_Data\Active\14\11.npy
# Mediapipe_Data\Active\14\12.npy
# Mediapipe_Data\Active\14\13.npy
# Mediapipe_Data\Active\14\14.npy
# Mediapipe_Data\Active\15\0.npy
# Mediapipe_Data\Active\15\1.npy
# Mediapipe_Data\Active\15\2.npy
# Mediapipe_Data\Active\15\3.npy
# Mediapipe_Data\Active\15\4.npy
# Mediapipe_Data\Active\15\5.npy
# Mediapipe_Data\Active\15\6.npy
# Mediapipe_Data\Active\15\7.npy
# Mediapipe_Data\Active\15\8.npy
# Mediapipe_Data\Active\15\9.npy
# Mediapipe_Data\Active\15\10.npy
# Mediapipe_Data\Active\15\11.npy
# Mediapipe_Data\Active\15\12.npy
# Mediapipe_Data\Active\15\13.npy
# Mediapipe_Data\Active\15\14.npy
# Mediapipe_Data\Active\16\0.npy
# Mediapipe_Data\Active\16\1.npy
# Mediapipe_Data\Active\16\2.npy
# Mediapipe_Data\Active\16\3.npy
# Mediapipe_Data\Active\16\4.npy
# Mediapipe_Data\Active\16\5.npy
# Mediapipe_Data\Active\16\6.npy
# Mediapipe_Data\Active\16\7.npy
# Mediapipe_Data\Active\16\8.npy
# Mediapipe_Data\Active\16\9.npy
# Mediapipe_Data\Active\16\10.npy
# Mediapipe_Data\Active\16\11.npy
# Mediapipe_Data\Active\16\12.npy
# Mediapipe_Data\Active\16\13.npy
# Mediapipe_Data\Active\16\14.npy
# Mediapipe_Data\Active\17\0.npy
# Mediapipe_Data\Active\17\1.npy
# Mediapipe_Data\Active\17\2.npy
# Mediapipe_Data\Active\17\3.npy
# Mediapipe_Data\Active\17\4.npy
# Mediapipe_Data\Active\17\5.npy
# Mediapipe_Data\Active\17\6.npy
# Mediapipe_Data\Active\17\7.npy
# Mediapipe_Data\Active\17\8.npy
# Mediapipe_Data\Active\17\9.npy
# Mediapipe_Data\Active\17\10.npy
# Mediapipe_Data\Active\17\11.npy
# Mediapipe_Data\Active\17\12.npy
# Mediapipe_Data\Active\17\13.npy
# Mediapipe_Data\Active\17\14.npy
# Mediapipe_Data\Active\18\0.npy
# Mediapipe_Data\Active\18\1.npy
# Mediapipe_Data\Active\18\2.npy
# Mediapipe_Data\Active\18\3.npy
# Mediapipe_Data\Active\18\4.npy
# Mediapipe_Data\Active\18\5.npy
# Mediapipe_Data\Active\18\6.npy
# Mediapipe_Data\Active\18\7.npy
# Mediapipe_Data\Active\18\8.npy
# Mediapipe_Data\Active\18\9.npy
# Mediapipe_Data\Active\18\10.npy
# Mediapipe_Data\Active\18\11.npy
# Mediapipe_Data\Active\18\12.npy
# Mediapipe_Data\Active\18\13.npy
# Mediapipe_Data\Active\18\14.npy
# Mediapipe_Data\Active\19\0.npy
# Mediapipe_Data\Active\19\1.npy
# Mediapipe_Data\Active\19\2.npy
# Mediapipe_Data\Active\19\3.npy
# Mediapipe_Data\Active\19\4.npy
# Mediapipe_Data\Active\19\5.npy
# Mediapipe_Data\Active\19\6.npy
# Mediapipe_Data\Active\19\7.npy
# Mediapipe_Data\Active\19\8.npy
# Mediapipe_Data\Active\19\9.npy
# Mediapipe_Data\Active\19\10.npy
# Mediapipe_Data\Active\19\11.npy
# Mediapipe_Data\Active\19\12.npy
# Mediapipe_Data\Active\19\13.npy
# Mediapipe_Data\Active\19\14.npy
# Mediapipe_Data\Active\20\0.npy
# Mediapipe_Data\Active\20\1.npy
# Mediapipe_Data\Active\20\2.npy
# Mediapipe_Data\Active\20\3.npy
# Mediapipe_Data\Active\20\4.npy
# Mediapipe_Data\Active\20\5.npy
# Mediapipe_Data\Active\20\6.npy
# Mediapipe_Data\Active\20\7.npy
# Mediapipe_Data\Active\20\8.npy
# Mediapipe_Data\Active\20\9.npy
# Mediapipe_Data\Active\20\10.npy
# Mediapipe_Data\Active\20\11.npy
# Mediapipe_Data\Active\20\12.npy
# Mediapipe_Data\Active\20\13.npy
# Mediapipe_Data\Active\20\14.npy
# Mediapipe_Data\Active\21\0.npy
# Mediapipe_Data\Active\21\1.npy
# Mediapipe_Data\Active\21\2.npy
# Mediapipe_Data\Active\21\3.npy
# Mediapipe_Data\Active\21\4.npy
# Mediapipe_Data\Active\21\5.npy
# Mediapipe_Data\Active\21\6.npy
# Mediapipe_Data\Active\21\7.npy
# Mediapipe_Data\Active\21\8.npy
# Mediapipe_Data\Active\21\9.npy
# Mediapipe_Data\Active\21\10.npy
# Mediapipe_Data\Active\21\11.npy
# Mediapipe_Data\Active\21\12.npy
# Mediapipe_Data\Active\21\13.npy
# Mediapipe_Data\Active\21\14.npy
# Mediapipe_Data\Active\22\0.npy
# Mediapipe_Data\Active\22\1.npy
# Mediapipe_Data\Active\22\2.npy
# Mediapipe_Data\Active\22\3.npy
# Mediapipe_Data\Active\22\4.npy
# Mediapipe_Data\Active\22\5.npy
# Mediapipe_Data\Active\22\6.npy
# Mediapipe_Data\Active\22\7.npy
# Mediapipe_Data\Active\22\8.npy
# Mediapipe_Data\Active\22\9.npy
# Mediapipe_Data\Active\22\10.npy
# Mediapipe_Data\Active\22\11.npy
# Mediapipe_Data\Active\22\12.npy
# Mediapipe_Data\Active\22\13.npy
# Mediapipe_Data\Active\22\14.npy
# Mediapipe_Data\Active\23\0.npy
# Mediapipe_Data\Active\23\1.npy
# Mediapipe_Data\Active\23\2.npy
# Mediapipe_Data\Active\23\3.npy
# Mediapipe_Data\Active\23\4.npy
# Mediapipe_Data\Active\23\5.npy
# Mediapipe_Data\Active\23\6.npy
# Mediapipe_Data\Active\23\7.npy
# Mediapipe_Data\Active\23\8.npy
# Mediapipe_Data\Active\23\9.npy
# Mediapipe_Data\Active\23\10.npy
# Mediapipe_Data\Active\23\11.npy
# Mediapipe_Data\Active\23\12.npy
# Mediapipe_Data\Active\23\13.npy
# Mediapipe_Data\Active\23\14.npy
# Mediapipe_Data\Active\24\0.npy
# Mediapipe_Data\Active\24\1.npy
# Mediapipe_Data\Active\24\2.npy
# Mediapipe_Data\Active\24\3.npy
# Mediapipe_Data\Active\24\4.npy
# Mediapipe_Data\Active\24\5.npy
# Mediapipe_Data\Active\24\6.npy
# Mediapipe_Data\Active\24\7.npy
# Mediapipe_Data\Active\24\8.npy
# Mediapipe_Data\Active\24\9.npy
# Mediapipe_Data\Active\24\10.npy
# Mediapipe_Data\Active\24\11.npy
# Mediapipe_Data\Active\24\12.npy
# Mediapipe_Data\Active\24\13.npy
# Mediapipe_Data\Active\24\14.npy
# Mediapipe_Data\Active\25\0.npy
# Mediapipe_Data\Active\25\1.npy
# Mediapipe_Data\Active\25\2.npy
# Mediapipe_Data\Active\25\3.npy
# Mediapipe_Data\Active\25\4.npy
# Mediapipe_Data\Active\25\5.npy
# Mediapipe_Data\Active\25\6.npy
# Mediapipe_Data\Active\25\7.npy
# Mediapipe_Data\Active\25\8.npy
# Mediapipe_Data\Active\25\9.npy
# Mediapipe_Data\Active\25\10.npy
# Mediapipe_Data\Active\25\11.npy
# Mediapipe_Data\Active\25\12.npy
# Mediapipe_Data\Active\25\13.npy
# Mediapipe_Data\Active\25\14.npy
# Mediapipe_Data\Active\26\0.npy
# Mediapipe_Data\Active\26\1.npy
# Mediapipe_Data\Active\26\2.npy
# Mediapipe_Data\Active\26\3.npy
# Mediapipe_Data\Active\26\4.npy
# Mediapipe_Data\Active\26\5.npy
# Mediapipe_Data\Active\26\6.npy
# Mediapipe_Data\Active\26\7.npy
# Mediapipe_Data\Active\26\8.npy
# Mediapipe_Data\Active\26\9.npy
# Mediapipe_Data\Active\26\10.npy
# Mediapipe_Data\Active\26\11.npy
# Mediapipe_Data\Active\26\12.npy
# Mediapipe_Data\Active\26\13.npy
# Mediapipe_Data\Active\26\14.npy
# Mediapipe_Data\Active\27\0.npy
# Mediapipe_Data\Active\27\1.npy
# Mediapipe_Data\Active\27\2.npy
# Mediapipe_Data\Active\27\3.npy
# Mediapipe_Data\Active\27\4.npy
# Mediapipe_Data\Active\27\5.npy
# Mediapipe_Data\Active\27\6.npy
# Mediapipe_Data\Active\27\7.npy
# Mediapipe_Data\Active\27\8.npy
# Mediapipe_Data\Active\27\9.npy
# Mediapipe_Data\Active\27\10.npy
# Mediapipe_Data\Active\27\11.npy
# Mediapipe_Data\Active\27\12.npy
# Mediapipe_Data\Active\27\13.npy
# Mediapipe_Data\Active\27\14.npy
# Mediapipe_Data\Active\28\0.npy
# Mediapipe_Data\Active\28\1.npy
# Mediapipe_Data\Active\28\2.npy
# Mediapipe_Data\Active\28\3.npy
# Mediapipe_Data\Active\28\4.npy
# Mediapipe_Data\Active\28\5.npy
# Mediapipe_Data\Active\28\6.npy
# Mediapipe_Data\Active\28\7.npy
# Mediapipe_Data\Active\28\8.npy
# Mediapipe_Data\Active\28\9.npy
# Mediapipe_Data\Active\28\10.npy
# Mediapipe_Data\Active\28\11.npy
# Mediapipe_Data\Active\28\12.npy
# Mediapipe_Data\Active\28\13.npy
# Mediapipe_Data\Active\28\14.npy
# Mediapipe_Data\Active\29\0.npy
# Mediapipe_Data\Active\29\1.npy
# Mediapipe_Data\Active\29\2.npy
# Mediapipe_Data\Active\29\3.npy
# Mediapipe_Data\Active\29\4.npy
# Mediapipe_Data\Active\29\5.npy
# Mediapipe_Data\Active\29\6.npy
# Mediapipe_Data\Active\29\7.npy
# Mediapipe_Data\Active\29\8.npy
# Mediapipe_Data\Active\29\9.npy
# Mediapipe_Data\Active\29\10.npy
# Mediapipe_Data\Active\29\11.npy
# Mediapipe_Data\Active\29\12.npy
# Mediapipe_Data\Active\29\13.npy
# Mediapipe_Data\Active\29\14.npy
# Mediapipe_Data\Active\30\0.npy
# Mediapipe_Data\Active\30\1.npy
# Mediapipe_Data\Active\30\2.npy
# Mediapipe_Data\Active\30\3.npy
# Mediapipe_Data\Active\30\4.npy
# Mediapipe_Data\Active\30\5.npy
# Mediapipe_Data\Active\30\6.npy
# Mediapipe_Data\Active\30\7.npy
# Mediapipe_Data\Active\30\8.npy
# Mediapipe_Data\Active\30\9.npy
# Mediapipe_Data\Active\30\10.npy
# Mediapipe_Data\Active\30\11.npy
# Mediapipe_Data\Active\30\12.npy
# Mediapipe_Data\Active\30\13.npy
# Mediapipe_Data\Active\30\14.npy
# Mediapipe_Data\Active\31\0.npy
# Mediapipe_Data\Active\31\1.npy
# Mediapipe_Data\Active\31\2.npy
# Mediapipe_Data\Active\31\3.npy
# Mediapipe_Data\Active\31\4.npy
# Mediapipe_Data\Active\31\5.npy
# Mediapipe_Data\Active\31\6.npy
# Mediapipe_Data\Active\31\7.npy
# Mediapipe_Data\Active\31\8.npy
# Mediapipe_Data\Active\31\9.npy
# Mediapipe_Data\Active\31\10.npy
# Mediapipe_Data\Active\31\11.npy
# Mediapipe_Data\Active\31\12.npy
# Mediapipe_Data\Active\31\13.npy
# Mediapipe_Data\Active\31\14.npy
# Mediapipe_Data\Active\32\0.npy
# Mediapipe_Data\Active\32\1.npy
# Mediapipe_Data\Active\32\2.npy
# Mediapipe_Data\Active\32\3.npy
# Mediapipe_Data\Active\32\4.npy
# Mediapipe_Data\Active\32\5.npy
# Mediapipe_Data\Active\32\6.npy
# Mediapipe_Data\Active\32\7.npy
# Mediapipe_Data\Active\32\8.npy
# Mediapipe_Data\Active\32\9.npy
# Mediapipe_Data\Active\32\10.npy
# Mediapipe_Data\Active\32\11.npy
# Mediapipe_Data\Active\32\12.npy
# Mediapipe_Data\Active\32\13.npy
# Mediapipe_Data\Active\32\14.npy
# Mediapipe_Data\Active\33\0.npy
# Mediapipe_Data\Active\33\1.npy
# Mediapipe_Data\Active\33\2.npy
# Mediapipe_Data\Active\33\3.npy
# Mediapipe_Data\Active\33\4.npy
# Mediapipe_Data\Active\33\5.npy
# Mediapipe_Data\Active\33\6.npy
# Mediapipe_Data\Active\33\7.npy
# Mediapipe_Data\Active\33\8.npy
# Mediapipe_Data\Active\33\9.npy
# Mediapipe_Data\Active\33\10.npy
# Mediapipe_Data\Active\33\11.npy
# Mediapipe_Data\Active\33\12.npy
# Mediapipe_Data\Active\33\13.npy
# Mediapipe_Data\Active\33\14.npy
# Mediapipe_Data\Active\34\0.npy
# Mediapipe_Data\Active\34\1.npy
# Mediapipe_Data\Active\34\2.npy
# Mediapipe_Data\Active\34\3.npy
# Mediapipe_Data\Active\34\4.npy
# Mediapipe_Data\Active\34\5.npy
# Mediapipe_Data\Active\34\6.npy
# Mediapipe_Data\Active\34\7.npy
# Mediapipe_Data\Active\34\8.npy
# Mediapipe_Data\Active\34\9.npy
# Mediapipe_Data\Active\34\10.npy
# Mediapipe_Data\Active\34\11.npy
# Mediapipe_Data\Active\34\12.npy
# Mediapipe_Data\Active\34\13.npy
# Mediapipe_Data\Active\34\14.npy
# Mediapipe_Data\Active\35\0.npy
# Mediapipe_Data\Active\35\1.npy
# Mediapipe_Data\Active\35\2.npy
# Mediapipe_Data\Active\35\3.npy
# Mediapipe_Data\Active\35\4.npy
# Mediapipe_Data\Active\35\5.npy
# Mediapipe_Data\Active\35\6.npy
# Mediapipe_Data\Active\35\7.npy
# Mediapipe_Data\Active\35\8.npy
# Mediapipe_Data\Active\35\9.npy
# Mediapipe_Data\Active\35\10.npy
# Mediapipe_Data\Active\35\11.npy
# Mediapipe_Data\Active\35\12.npy
# Mediapipe_Data\Active\35\13.npy
# Mediapipe_Data\Active\35\14.npy
# Mediapipe_Data\Active\36\0.npy
# Mediapipe_Data\Active\36\1.npy
# Mediapipe_Data\Active\36\2.npy
# Mediapipe_Data\Active\36\3.npy
# Mediapipe_Data\Active\36\4.npy
# Mediapipe_Data\Active\36\5.npy
# Mediapipe_Data\Active\36\6.npy
# Mediapipe_Data\Active\36\7.npy
# Mediapipe_Data\Active\36\8.npy
# Mediapipe_Data\Active\36\9.npy
# Mediapipe_Data\Active\36\10.npy
# Mediapipe_Data\Active\36\11.npy
# Mediapipe_Data\Active\36\12.npy
# Mediapipe_Data\Active\36\13.npy
# Mediapipe_Data\Active\36\14.npy
# Mediapipe_Data\Active\37\0.npy
# Mediapipe_Data\Active\37\1.npy
# Mediapipe_Data\Active\37\2.npy
# Mediapipe_Data\Active\37\3.npy
# Mediapipe_Data\Active\37\4.npy
# Mediapipe_Data\Active\37\5.npy
# Mediapipe_Data\Active\37\6.npy
# Mediapipe_Data\Active\37\7.npy
# Mediapipe_Data\Active\37\8.npy
# Mediapipe_Data\Active\37\9.npy
# Mediapipe_Data\Active\37\10.npy
# Mediapipe_Data\Active\37\11.npy
# Mediapipe_Data\Active\37\12.npy
# Mediapipe_Data\Active\37\13.npy
# Mediapipe_Data\Active\37\14.npy
# Mediapipe_Data\Active\38\0.npy
# Mediapipe_Data\Active\38\1.npy
# Mediapipe_Data\Active\38\2.npy
# Mediapipe_Data\Active\38\3.npy
# Mediapipe_Data\Active\38\4.npy
# Mediapipe_Data\Active\38\5.npy
# Mediapipe_Data\Active\38\6.npy
# Mediapipe_Data\Active\38\7.npy
# Mediapipe_Data\Active\38\8.npy
# Mediapipe_Data\Active\38\9.npy
# Mediapipe_Data\Active\38\10.npy
# Mediapipe_Data\Active\38\11.npy
# Mediapipe_Data\Active\38\12.npy
# Mediapipe_Data\Active\38\13.npy
# Mediapipe_Data\Active\38\14.npy
# Mediapipe_Data\Active\39\0.npy
# Mediapipe_Data\Active\39\1.npy
# Mediapipe_Data\Active\39\2.npy
# Mediapipe_Data\Active\39\3.npy
# Mediapipe_Data\Active\39\4.npy
# Mediapipe_Data\Active\39\5.npy
# Mediapipe_Data\Active\39\6.npy
# Mediapipe_Data\Active\39\7.npy
# Mediapipe_Data\Active\39\8.npy
# Mediapipe_Data\Active\39\9.npy
# Mediapipe_Data\Active\39\10.npy
# Mediapipe_Data\Active\39\11.npy
# Mediapipe_Data\Active\39\12.npy
# Mediapipe_Data\Active\39\13.npy
# Mediapipe_Data\Active\39\14.npy
# Mediapipe_Data\Active\40\0.npy
# Mediapipe_Data\Active\40\1.npy
# Mediapipe_Data\Active\40\2.npy
# Mediapipe_Data\Active\40\3.npy
# Mediapipe_Data\Active\40\4.npy
# Mediapipe_Data\Active\40\5.npy
# Mediapipe_Data\Active\40\6.npy
# Mediapipe_Data\Active\40\7.npy
# Mediapipe_Data\Active\40\8.npy
# Mediapipe_Data\Active\40\9.npy
# Mediapipe_Data\Active\40\10.npy
# Mediapipe_Data\Active\40\11.npy
# Mediapipe_Data\Active\40\12.npy
# Mediapipe_Data\Active\40\13.npy
# Mediapipe_Data\Active\40\14.npy
# Mediapipe_Data\Active\41\0.npy
# Mediapipe_Data\Active\41\1.npy
# Mediapipe_Data\Active\41\2.npy
# Mediapipe_Data\Active\41\3.npy
# Mediapipe_Data\Active\41\4.npy
# Mediapipe_Data\Active\41\5.npy
# Mediapipe_Data\Active\41\6.npy
# Mediapipe_Data\Active\41\7.npy
# Mediapipe_Data\Active\41\8.npy
# Mediapipe_Data\Active\41\9.npy
# Mediapipe_Data\Active\41\10.npy
# Mediapipe_Data\Active\41\11.npy
# Mediapipe_Data\Active\41\12.npy
# Mediapipe_Data\Active\41\13.npy
# Mediapipe_Data\Active\41\14.npy
# Mediapipe_Data\Active\42\0.npy
# Mediapipe_Data\Active\42\1.npy
# Mediapipe_Data\Active\42\2.npy
# Mediapipe_Data\Active\42\3.npy
# Mediapipe_Data\Active\42\4.npy
# Mediapipe_Data\Active\42\5.npy
# Mediapipe_Data\Active\42\6.npy
# Mediapipe_Data\Active\42\7.npy
# Mediapipe_Data\Active\42\8.npy
# Mediapipe_Data\Active\42\9.npy
# Mediapipe_Data\Active\42\10.npy
# Mediapipe_Data\Active\42\11.npy
# Mediapipe_Data\Active\42\12.npy
# Mediapipe_Data\Active\42\13.npy
# Mediapipe_Data\Active\42\14.npy
# Mediapipe_Data\Active\43\0.npy
# Mediapipe_Data\Active\43\1.npy
# Mediapipe_Data\Active\43\2.npy
# Mediapipe_Data\Active\43\3.npy
# Mediapipe_Data\Active\43\4.npy
# Mediapipe_Data\Active\43\5.npy
# Mediapipe_Data\Active\43\6.npy
# Mediapipe_Data\Active\43\7.npy
# Mediapipe_Data\Active\43\8.npy
# Mediapipe_Data\Active\43\9.npy
# Mediapipe_Data\Active\43\10.npy
# Mediapipe_Data\Active\43\11.npy
# Mediapipe_Data\Active\43\12.npy
# Mediapipe_Data\Active\43\13.npy
# Mediapipe_Data\Active\43\14.npy
# Mediapipe_Data\Active\44\0.npy
# Mediapipe_Data\Active\44\1.npy
# Mediapipe_Data\Active\44\2.npy
# Mediapipe_Data\Active\44\3.npy
# Mediapipe_Data\Active\44\4.npy
# Mediapipe_Data\Active\44\5.npy
# Mediapipe_Data\Active\44\6.npy
# Mediapipe_Data\Active\44\7.npy
# Mediapipe_Data\Active\44\8.npy
# Mediapipe_Data\Active\44\9.npy
# Mediapipe_Data\Active\44\10.npy
# Mediapipe_Data\Active\44\11.npy
# Mediapipe_Data\Active\44\12.npy
# Mediapipe_Data\Active\44\13.npy
# Mediapipe_Data\Active\44\14.npy
# Mediapipe_Data\Active\45\0.npy
# Mediapipe_Data\Active\45\1.npy
# Mediapipe_Data\Active\45\2.npy
# Mediapipe_Data\Active\45\3.npy
# Mediapipe_Data\Active\45\4.npy
# Mediapipe_Data\Active\45\5.npy
# Mediapipe_Data\Active\45\6.npy
# Mediapipe_Data\Active\45\7.npy
# Mediapipe_Data\Active\45\8.npy
# Mediapipe_Data\Active\45\9.npy
# Mediapipe_Data\Active\45\10.npy
# Mediapipe_Data\Active\45\11.npy
# Mediapipe_Data\Active\45\12.npy
# Mediapipe_Data\Active\45\13.npy
# Mediapipe_Data\Active\45\14.npy
# Mediapipe_Data\Active\46\0.npy
# Mediapipe_Data\Active\46\1.npy
# Mediapipe_Data\Active\46\2.npy
# Mediapipe_Data\Active\46\3.npy
# Mediapipe_Data\Active\46\4.npy
# Mediapipe_Data\Active\46\5.npy
# Mediapipe_Data\Active\46\6.npy
# Mediapipe_Data\Active\46\7.npy
# Mediapipe_Data\Active\46\8.npy
# Mediapipe_Data\Active\46\9.npy
# Mediapipe_Data\Active\46\10.npy
# Mediapipe_Data\Active\46\11.npy
# Mediapipe_Data\Active\46\12.npy
# Mediapipe_Data\Active\46\13.npy
# Mediapipe_Data\Active\46\14.npy
# Mediapipe_Data\Active\47\0.npy
# Mediapipe_Data\Active\47\1.npy
# Mediapipe_Data\Active\47\2.npy
# Mediapipe_Data\Active\47\3.npy
# Mediapipe_Data\Active\47\4.npy
# Mediapipe_Data\Active\47\5.npy
# Mediapipe_Data\Active\47\6.npy
# Mediapipe_Data\Active\47\7.npy
# Mediapipe_Data\Active\47\8.npy
# Mediapipe_Data\Active\47\9.npy
# Mediapipe_Data\Active\47\10.npy
# Mediapipe_Data\Active\47\11.npy
# Mediapipe_Data\Active\47\12.npy
# Mediapipe_Data\Active\47\13.npy
# Mediapipe_Data\Active\47\14.npy
# Mediapipe_Data\Active\48\0.npy
# Mediapipe_Data\Active\48\1.npy
# Mediapipe_Data\Active\48\2.npy
# Mediapipe_Data\Active\48\3.npy
# Mediapipe_Data\Active\48\4.npy
# Mediapipe_Data\Active\48\5.npy
# Mediapipe_Data\Active\48\6.npy
# Mediapipe_Data\Active\48\7.npy
# Mediapipe_Data\Active\48\8.npy
# Mediapipe_Data\Active\48\9.npy
# Mediapipe_Data\Active\48\10.npy
# Mediapipe_Data\Active\48\11.npy
# Mediapipe_Data\Active\48\12.npy
# Mediapipe_Data\Active\48\13.npy
# Mediapipe_Data\Active\48\14.npy
# Mediapipe_Data\Active\49\0.npy
# Mediapipe_Data\Active\49\1.npy
# Mediapipe_Data\Active\49\2.npy
# Mediapipe_Data\Active\49\3.npy
# Mediapipe_Data\Active\49\4.npy
# Mediapipe_Data\Active\49\5.npy
# Mediapipe_Data\Active\49\6.npy
# Mediapipe_Data\Active\49\7.npy
# Mediapipe_Data\Active\49\8.npy
# Mediapipe_Data\Active\49\9.npy
# Mediapipe_Data\Active\49\10.npy
# Mediapipe_Data\Active\49\11.npy
# Mediapipe_Data\Active\49\12.npy
# Mediapipe_Data\Active\49\13.npy
# Mediapipe_Data\Active\49\14.npy
# Mediapipe_Data\Active\50\0.npy
# Mediapipe_Data\Active\50\1.npy
# Mediapipe_Data\Active\50\2.npy
# Mediapipe_Data\Active\50\3.npy
# Mediapipe_Data\Active\50\4.npy
# Mediapipe_Data\Active\50\5.npy
# Mediapipe_Data\Active\50\6.npy
# Mediapipe_Data\Active\50\7.npy
# Mediapipe_Data\Active\50\8.npy
# Mediapipe_Data\Active\50\9.npy
# Mediapipe_Data\Active\50\10.npy
# Mediapipe_Data\Active\50\11.npy
# Mediapipe_Data\Active\50\12.npy
# Mediapipe_Data\Active\50\13.npy
# Mediapipe_Data\Active\50\14.npy
# Mediapipe_Data\Active\51\0.npy
# Mediapipe_Data\Active\51\1.npy
# Mediapipe_Data\Active\51\2.npy
# Mediapipe_Data\Active\51\3.npy
# Mediapipe_Data\Active\51\4.npy
# Mediapipe_Data\Active\51\5.npy
# Mediapipe_Data\Active\51\6.npy
# Mediapipe_Data\Active\51\7.npy
# Mediapipe_Data\Active\51\8.npy
# Mediapipe_Data\Active\51\9.npy
# Mediapipe_Data\Active\51\10.npy
# Mediapipe_Data\Active\51\11.npy
# Mediapipe_Data\Active\51\12.npy
# Mediapipe_Data\Active\51\13.npy
# Mediapipe_Data\Active\51\14.npy
# Mediapipe_Data\Active\52\0.npy
# Mediapipe_Data\Active\52\1.npy
# Mediapipe_Data\Active\52\2.npy
# Mediapipe_Data\Active\52\3.npy
# Mediapipe_Data\Active\52\4.npy
# Mediapipe_Data\Active\52\5.npy
# Mediapipe_Data\Active\52\6.npy
# Mediapipe_Data\Active\52\7.npy
# Mediapipe_Data\Active\52\8.npy
# Mediapipe_Data\Active\52\9.npy
# Mediapipe_Data\Active\52\10.npy
# Mediapipe_Data\Active\52\11.npy
# Mediapipe_Data\Active\52\12.npy
# Mediapipe_Data\Active\52\13.npy
# Mediapipe_Data\Active\52\14.npy
# Mediapipe_Data\Active\53\0.npy
# Mediapipe_Data\Active\53\1.npy
# Mediapipe_Data\Active\53\2.npy
# Mediapipe_Data\Active\53\3.npy
# Mediapipe_Data\Active\53\4.npy
# Mediapipe_Data\Active\53\5.npy
# Mediapipe_Data\Active\53\6.npy
# Mediapipe_Data\Active\53\7.npy
# Mediapipe_Data\Active\53\8.npy
# Mediapipe_Data\Active\53\9.npy
# Mediapipe_Data\Active\53\10.npy
# Mediapipe_Data\Active\53\11.npy
# Mediapipe_Data\Active\53\12.npy
# Mediapipe_Data\Active\53\13.npy
# Mediapipe_Data\Active\53\14.npy
# Mediapipe_Data\Active\54\0.npy
# Mediapipe_Data\Active\54\1.npy
# Mediapipe_Data\Active\54\2.npy
# Mediapipe_Data\Active\54\3.npy
# Mediapipe_Data\Active\54\4.npy
# Mediapipe_Data\Active\54\5.npy
# Mediapipe_Data\Active\54\6.npy
# Mediapipe_Data\Active\54\7.npy
# Mediapipe_Data\Active\54\8.npy
# Mediapipe_Data\Active\54\9.npy
# Mediapipe_Data\Active\54\10.npy
# Mediapipe_Data\Active\54\11.npy
# Mediapipe_Data\Active\54\12.npy
# Mediapipe_Data\Active\54\13.npy
# Mediapipe_Data\Active\54\14.npy
# Mediapipe_Data\Active\55\0.npy
# Mediapipe_Data\Active\55\1.npy
# Mediapipe_Data\Active\55\2.npy
# Mediapipe_Data\Active\55\3.npy
# Mediapipe_Data\Active\55\4.npy
# Mediapipe_Data\Active\55\5.npy
# Mediapipe_Data\Active\55\6.npy
# Mediapipe_Data\Active\55\7.npy
# Mediapipe_Data\Active\55\8.npy
# Mediapipe_Data\Active\55\9.npy
# Mediapipe_Data\Active\55\10.npy
# Mediapipe_Data\Active\55\11.npy
# Mediapipe_Data\Active\55\12.npy
# Mediapipe_Data\Active\55\13.npy
# Mediapipe_Data\Active\55\14.npy
# Mediapipe_Data\Active\56\0.npy
# Mediapipe_Data\Active\56\1.npy
# Mediapipe_Data\Active\56\2.npy
# Mediapipe_Data\Active\56\3.npy
# Mediapipe_Data\Active\56\4.npy
# Mediapipe_Data\Active\56\5.npy
# Mediapipe_Data\Active\56\6.npy
# Mediapipe_Data\Active\56\7.npy
# Mediapipe_Data\Active\56\8.npy
# Mediapipe_Data\Active\56\9.npy
# Mediapipe_Data\Active\56\10.npy
# Mediapipe_Data\Active\56\11.npy
# Mediapipe_Data\Active\56\12.npy
# Mediapipe_Data\Active\56\13.npy
# Mediapipe_Data\Active\56\14.npy
# Mediapipe_Data\Active\66\10.npy
# Mediapipe_Data\Active\66\11.npy
# Mediapipe_Data\Active\66\12.npy
# Mediapipe_Data\Active\66\13.npy
# Mediapipe_Data\Active\66\14.npy
# Mediapipe_Data\Active\67\0.npy
# Mediapipe_Data\Active\67\1.npy
# Mediapipe_Data\Active\67\2.npy
# Mediapipe_Data\Active\67\3.npy
# Mediapipe_Data\Active\67\4.npy
# Mediapipe_Data\Active\67\5.npy
# Mediapipe_Data\Active\67\6.npy
# Mediapipe_Data\Active\67\7.npy
# Mediapipe_Data\Active\67\8.npy
# Mediapipe_Data\Active\67\9.npy
# Mediapipe_Data\Active\67\10.npy
# Mediapipe_Data\Active\67\11.npy
# Mediapipe_Data\Active\67\12.npy
# Mediapipe_Data\Active\67\13.npy
# Mediapipe_Data\Active\67\14.npy
# Mediapipe_Data\Active\68\0.npy
# Mediapipe_Data\Active\68\1.npy
# Mediapipe_Data\Active\68\2.npy
# Mediapipe_Data\Active\68\3.npy
# Mediapipe_Data\Active\68\4.npy
# Mediapipe_Data\Active\68\5.npy
# Mediapipe_Data\Active\68\6.npy
# Mediapipe_Data\Active\68\7.npy
# Mediapipe_Data\Active\68\8.npy
# Mediapipe_Data\Active\68\9.npy
# Mediapipe_Data\Active\68\10.npy
# Mediapipe_Data\Active\68\11.npy
# Mediapipe_Data\Active\68\12.npy
# Mediapipe_Data\Active\68\13.npy
# Mediapipe_Data\Active\68\14.npy
# Mediapipe_Data\Active\69\0.npy
# Mediapipe_Data\Active\69\1.npy
# Mediapipe_Data\Active\69\2.npy
# Mediapipe_Data\Active\69\3.npy
# Mediapipe_Data\Active\69\4.npy
# Mediapipe_Data\Active\69\5.npy
# Mediapipe_Data\Active\69\6.npy
# Mediapipe_Data\Active\69\7.npy
# Mediapipe_Data\Active\69\8.npy
# Mediapipe_Data\Active\69\9.npy
# Mediapipe_Data\Active\69\10.npy
# Mediapipe_Data\Active\69\11.npy
# Mediapipe_Data\Active\69\12.npy
# Mediapipe_Data\Active\69\13.npy
# Mediapipe_Data\Active\69\14.npy
# Mediapipe_Data\Active\70\0.npy
# Mediapipe_Data\Active\70\1.npy
# Mediapipe_Data\Active\70\2.npy
# Mediapipe_Data\Active\70\3.npy
# Mediapipe_Data\Active\70\4.npy
# Mediapipe_Data\Active\70\5.npy
# Mediapipe_Data\Active\70\6.npy
# Mediapipe_Data\Active\70\7.npy
# Mediapipe_Data\Active\70\8.npy
# Mediapipe_Data\Active\70\9.npy
# Mediapipe_Data\Active\70\10.npy
# Mediapipe_Data\Active\70\11.npy
# Mediapipe_Data\Active\70\12.npy
# Mediapipe_Data\Active\70\13.npy
# Mediapipe_Data\Active\70\14.npy
# Mediapipe_Data\Active\71\0.npy
# Mediapipe_Data\Active\71\1.npy
# Mediapipe_Data\Active\71\2.npy
# Mediapipe_Data\Active\71\3.npy
# Mediapipe_Data\Active\71\4.npy
# Mediapipe_Data\Active\71\5.npy
# Mediapipe_Data\Active\71\6.npy
# Mediapipe_Data\Active\71\7.npy
# Mediapipe_Data\Active\71\8.npy
# Mediapipe_Data\Active\71\9.npy
# Mediapipe_Data\Active\71\10.npy
# Mediapipe_Data\Active\71\11.npy
# Mediapipe_Data\Active\71\12.npy
# Mediapipe_Data\Active\71\13.npy
# Mediapipe_Data\Active\71\14.npy
# Mediapipe_Data\Active\72\0.npy
# Mediapipe_Data\Active\72\1.npy
# Mediapipe_Data\Active\72\2.npy
# Mediapipe_Data\Active\72\3.npy
# Mediapipe_Data\Active\72\4.npy
# Mediapipe_Data\Active\72\5.npy
# Mediapipe_Data\Active\72\6.npy
# Mediapipe_Data\Active\72\7.npy
# Mediapipe_Data\Active\72\8.npy
# Mediapipe_Data\Active\72\9.npy
# Mediapipe_Data\Active\72\10.npy
# Mediapipe_Data\Active\72\11.npy
# Mediapipe_Data\Active\72\12.npy
# Mediapipe_Data\Active\72\13.npy
# Mediapipe_Data\Active\72\14.npy
# Mediapipe_Data\Active\73\0.npy
# Mediapipe_Data\Active\73\1.npy
# Mediapipe_Data\Active\73\2.npy
# Mediapipe_Data\Active\73\3.npy
# Mediapipe_Data\Active\73\4.npy
# Mediapipe_Data\Active\73\5.npy
# Mediapipe_Data\Active\73\6.npy
# Mediapipe_Data\Active\73\7.npy
# Mediapipe_Data\Active\73\8.npy
# Mediapipe_Data\Active\73\9.npy
# Mediapipe_Data\Active\73\10.npy
# Mediapipe_Data\Active\73\11.npy
# Mediapipe_Data\Active\73\12.npy
# Mediapipe_Data\Active\73\13.npy
# Mediapipe_Data\Active\73\14.npy
# Mediapipe_Data\Active\74\0.npy
# Mediapipe_Data\Active\74\1.npy
# Mediapipe_Data\Active\74\2.npy
# Mediapipe_Data\Active\74\3.npy
# Mediapipe_Data\Active\74\4.npy
# Mediapipe_Data\Active\74\5.npy
# Mediapipe_Data\Active\74\6.npy
# Mediapipe_Data\Active\74\7.npy
# Mediapipe_Data\Active\74\8.npy
# Mediapipe_Data\Active\74\9.npy
# Mediapipe_Data\Active\74\10.npy
# Mediapipe_Data\Active\74\11.npy
# Mediapipe_Data\Active\74\12.npy
# Mediapipe_Data\Active\74\13.npy
# Mediapipe_Data\Active\74\14.npy
# Mediapipe_Data\Active\75\0.npy
# Mediapipe_Data\Active\75\1.npy
# Mediapipe_Data\Active\75\2.npy
# Mediapipe_Data\Active\75\3.npy
# Mediapipe_Data\Active\75\4.npy
# Mediapipe_Data\Active\75\5.npy
# Mediapipe_Data\Active\75\6.npy
# Mediapipe_Data\Active\75\7.npy
# Mediapipe_Data\Active\75\8.npy
# Mediapipe_Data\Active\75\9.npy
# Mediapipe_Data\Active\75\10.npy
# Mediapipe_Data\Active\75\11.npy
# Mediapipe_Data\Active\75\12.npy
# Mediapipe_Data\Active\75\13.npy
# Mediapipe_Data\Active\75\14.npy
# Mediapipe_Data\Active\76\0.npy
# Mediapipe_Data\Active\76\1.npy
# Mediapipe_Data\Active\76\2.npy
# Mediapipe_Data\Active\76\3.npy
# Mediapipe_Data\Active\76\4.npy
# Mediapipe_Data\Active\76\5.npy
# Mediapipe_Data\Active\81\4.npy
# Mediapipe_Data\Active\81\5.npy
# Mediapipe_Data\Active\81\6.npy
# Mediapipe_Data\Active\81\7.npy
# Mediapipe_Data\Active\81\8.npy
# Mediapipe_Data\Active\81\9.npy
# Mediapipe_Data\Active\81\10.npy
# Mediapipe_Data\Active\81\11.npy
# Mediapipe_Data\Active\81\12.npy
# Mediapipe_Data\Active\81\13.npy
# Mediapipe_Data\Active\81\14.npy
# Mediapipe_Data\Active\82\0.npy
# Mediapipe_Data\Active\82\1.npy
# Mediapipe_Data\Active\82\2.npy
# Mediapipe_Data\Active\82\3.npy
# Mediapipe_Data\Active\82\4.npy
# Mediapipe_Data\Active\82\5.npy
# Mediapipe_Data\Active\82\6.npy
# Mediapipe_Data\Active\82\7.npy
# Mediapipe_Data\Active\82\8.npy
# Mediapipe_Data\Active\82\9.npy
# Mediapipe_Data\Active\82\10.npy
# Mediapipe_Data\Active\82\11.npy
# Mediapipe_Data\Active\82\12.npy
# Mediapipe_Data\Active\82\13.npy
# Mediapipe_Data\Active\82\14.npy
# Mediapipe_Data\Active\83\0.npy
# Mediapipe_Data\Active\83\1.npy
# Mediapipe_Data\Active\83\2.npy
# Mediapipe_Data\Active\83\3.npy
# Mediapipe_Data\Active\83\4.npy
# Mediapipe_Data\Active\83\5.npy
# Mediapipe_Data\Active\83\6.npy
# Mediapipe_Data\Active\83\7.npy
# Mediapipe_Data\Active\83\8.npy
# Mediapipe_Data\Active\83\9.npy
# Mediapipe_Data\Active\83\10.npy
# Mediapipe_Data\Active\83\11.npy
# Mediapipe_Data\Active\83\12.npy
# Mediapipe_Data\Active\83\13.npy
# Mediapipe_Data\Active\83\14.npy
# Mediapipe_Data\Active\84\0.npy
# Mediapipe_Data\Active\84\1.npy
# Mediapipe_Data\Active\84\2.npy
# Mediapipe_Data\Active\84\3.npy
# Mediapipe_Data\Active\84\4.npy
# Mediapipe_Data\Active\84\5.npy
# Mediapipe_Data\Active\84\6.npy
# Mediapipe_Data\Active\84\7.npy
# Mediapipe_Data\Active\84\8.npy
# Mediapipe_Data\Active\84\9.npy
# Mediapipe_Data\Active\84\10.npy
# Mediapipe_Data\Active\84\11.npy
# Mediapipe_Data\Active\84\12.npy
# Mediapipe_Data\Active\84\13.npy
# Mediapipe_Data\Active\84\14.npy
# Mediapipe_Data\Active\85\0.npy
# Mediapipe_Data\Active\85\1.npy
# Mediapipe_Data\Active\85\2.npy
# Mediapipe_Data\Active\85\3.npy
# Mediapipe_Data\Active\85\4.npy
# Mediapipe_Data\Active\85\5.npy
# Mediapipe_Data\Active\85\6.npy
# Mediapipe_Data\Active\85\7.npy
# Mediapipe_Data\Active\85\8.npy
# Mediapipe_Data\Active\85\9.npy
# Mediapipe_Data\Active\85\10.npy
# Mediapipe_Data\Active\85\11.npy
# Mediapipe_Data\Active\85\12.npy
# Mediapipe_Data\Active\85\13.npy
# Mediapipe_Data\Active\85\14.npy
# Mediapipe_Data\Active\86\0.npy
# Mediapipe_Data\Active\86\1.npy
# Mediapipe_Data\Active\86\2.npy
# Mediapipe_Data\Active\86\3.npy
# Mediapipe_Data\Active\86\4.npy
# Mediapipe_Data\Active\86\5.npy
# Mediapipe_Data\Active\86\6.npy
# Mediapipe_Data\Active\86\7.npy
# Mediapipe_Data\Active\86\8.npy
# Mediapipe_Data\Active\86\9.npy
# Mediapipe_Data\Active\86\10.npy
# Mediapipe_Data\Active\86\11.npy
# Mediapipe_Data\Active\86\12.npy
# Mediapipe_Data\Active\86\13.npy
# Mediapipe_Data\Active\86\14.npy
# Mediapipe_Data\Active\87\0.npy
# Mediapipe_Data\Active\87\1.npy
# Mediapipe_Data\Active\87\2.npy
# Mediapipe_Data\Active\87\3.npy
# Mediapipe_Data\Active\87\4.npy
# Mediapipe_Data\Active\87\5.npy
# Mediapipe_Data\Active\87\6.npy
# Mediapipe_Data\Active\87\7.npy
# Mediapipe_Data\Active\87\8.npy
# Mediapipe_Data\Active\87\9.npy
# Mediapipe_Data\Active\87\10.npy
# Mediapipe_Data\Active\87\11.npy
# Mediapipe_Data\Active\87\12.npy
# Mediapipe_Data\Active\87\13.npy
# Mediapipe_Data\Active\87\14.npy
# Mediapipe_Data\Active\88\0.npy
# Mediapipe_Data\Active\88\1.npy
# Mediapipe_Data\Active\88\2.npy
# Mediapipe_Data\Active\88\3.npy
# Mediapipe_Data\Active\88\4.npy
# Mediapipe_Data\Active\88\5.npy
# Mediapipe_Data\Active\88\6.npy
# Mediapipe_Data\Active\88\7.npy
# Mediapipe_Data\Active\88\8.npy
# Mediapipe_Data\Active\88\9.npy
# Mediapipe_Data\Active\88\10.npy
# Mediapipe_Data\Active\88\11.npy
# Mediapipe_Data\Active\88\12.npy
# Mediapipe_Data\Active\88\13.npy
# Mediapipe_Data\Active\88\14.npy
# Mediapipe_Data\Active\89\0.npy
# Mediapipe_Data\Active\89\1.npy
# Mediapipe_Data\Active\89\2.npy
# Mediapipe_Data\Active\89\3.npy
# Mediapipe_Data\Active\89\4.npy
# Mediapipe_Data\Active\89\5.npy
# Mediapipe_Data\Active\89\6.npy
# Mediapipe_Data\Active\89\7.npy
# Mediapipe_Data\Active\89\8.npy
# Mediapipe_Data\Active\89\9.npy
# Mediapipe_Data\Active\89\10.npy
# Mediapipe_Data\Active\89\11.npy
# Mediapipe_Data\Active\89\12.npy
# Mediapipe_Data\Active\89\13.npy
# Mediapipe_Data\Active\89\14.npy
# Mediapipe_Data\Active\90\0.npy
# Mediapipe_Data\Active\90\1.npy
# Mediapipe_Data\Active\90\2.npy
# Mediapipe_Data\Active\90\3.npy
# Mediapipe_Data\Active\90\4.npy
# Mediapipe_Data\Active\90\5.npy
# Mediapipe_Data\Active\90\6.npy
# Mediapipe_Data\Active\90\7.npy
# Mediapipe_Data\Active\90\8.npy
# Mediapipe_Data\Active\90\9.npy
# Mediapipe_Data\Active\90\10.npy
# Mediapipe_Data\Active\90\11.npy
# Mediapipe_Data\Active\90\12.npy
# Mediapipe_Data\Active\90\13.npy
# Mediapipe_Data\Active\90\14.npy
# Mediapipe_Data\Active\91\0.npy
# Mediapipe_Data\Active\91\1.npy
# Mediapipe_Data\Active\91\2.npy
# Mediapipe_Data\Active\91\3.npy
# Mediapipe_Data\Active\91\4.npy
# Mediapipe_Data\Active\91\5.npy
# Mediapipe_Data\Active\91\6.npy
# Mediapipe_Data\Active\91\7.npy
# Mediapipe_Data\Active\91\8.npy
# Mediapipe_Data\Active\91\9.npy
# Mediapipe_Data\Active\91\10.npy
# Mediapipe_Data\Active\91\11.npy
# Mediapipe_Data\Active\91\12.npy
# Mediapipe_Data\Active\91\13.npy
# Mediapipe_Data\Active\91\14.npy
# Mediapipe_Data\Active\92\0.npy
# Mediapipe_Data\Active\92\1.npy
# Mediapipe_Data\Active\92\2.npy
# Mediapipe_Data\Active\92\3.npy
# Mediapipe_Data\Active\92\4.npy
# Mediapipe_Data\Active\92\5.npy
# Mediapipe_Data\Active\92\6.npy
# Mediapipe_Data\Active\92\7.npy
# Mediapipe_Data\Active\92\8.npy
# Mediapipe_Data\Active\92\9.npy
# Mediapipe_Data\Active\92\10.npy
# Mediapipe_Data\Active\92\11.npy
# Mediapipe_Data\Active\92\12.npy
# Mediapipe_Data\Active\92\13.npy
# Mediapipe_Data\Active\92\14.npy
# Mediapipe_Data\Active\93\0.npy
# Mediapipe_Data\Active\93\1.npy
# Mediapipe_Data\Active\93\2.npy
# Mediapipe_Data\Active\93\3.npy
# Mediapipe_Data\Active\93\4.npy
# Mediapipe_Data\Active\93\5.npy
# Mediapipe_Data\Active\93\6.npy
# Mediapipe_Data\Active\93\7.npy
# Mediapipe_Data\Active\93\8.npy
# Mediapipe_Data\Active\93\9.npy
# Mediapipe_Data\Active\93\10.npy
# Mediapipe_Data\Active\93\11.npy
# Mediapipe_Data\Active\93\12.npy
# Mediapipe_Data\Active\93\13.npy
# Mediapipe_Data\Active\93\14.npy
# Mediapipe_Data\Active\94\0.npy
# Mediapipe_Data\Active\94\1.npy
# Mediapipe_Data\Active\94\2.npy
# Mediapipe_Data\Active\94\3.npy
# Mediapipe_Data\Active\94\4.npy
# Mediapipe_Data\Active\94\5.npy
# Mediapipe_Data\Active\94\6.npy
# Mediapipe_Data\Active\94\7.npy
# Mediapipe_Data\Active\94\8.npy
# Mediapipe_Data\Active\94\9.npy
# Mediapipe_Data\Active\94\10.npy
# Mediapipe_Data\Active\94\11.npy
# Mediapipe_Data\Active\94\12.npy
# Mediapipe_Data\Active\94\13.npy
# Mediapipe_Data\Active\94\14.npy
# Mediapipe_Data\Active\95\0.npy
# Mediapipe_Data\Active\95\1.npy
# Mediapipe_Data\Active\95\2.npy
# Mediapipe_Data\Active\95\3.npy
# Mediapipe_Data\Active\95\4.npy
# Mediapipe_Data\Active\95\5.npy
# Mediapipe_Data\Active\95\6.npy
# Mediapipe_Data\Active\95\7.npy
# Mediapipe_Data\Active\95\8.npy
# Mediapipe_Data\Active\95\9.npy
# Mediapipe_Data\Active\95\10.npy
# Mediapipe_Data\Active\95\11.npy
# Mediapipe_Data\Draw\125\7.npy
# Mediapipe_Data\Draw\125\8.npy
# Mediapipe_Data\Draw\125\9.npy
# Mediapipe_Data\Draw\125\10.npy
# Mediapipe_Data\Draw\125\11.npy
# Mediapipe_Data\Draw\125\12.npy
# Mediapipe_Data\Draw\125\13.npy
# Mediapipe_Data\Draw\125\14.npy
# Mediapipe_Data\Draw\126\0.npy
# Mediapipe_Data\Draw\126\1.npy
# Mediapipe_Data\Draw\126\2.npy
# Mediapipe_Data\Draw\126\3.npy
# Mediapipe_Data\Draw\126\4.npy
# Mediapipe_Data\Draw\126\5.npy
# Mediapipe_Data\Draw\126\6.npy
# Mediapipe_Data\Draw\126\7.npy
# Mediapipe_Data\Draw\126\8.npy
# Mediapipe_Data\Draw\126\9.npy
# Mediapipe_Data\Draw\126\10.npy
# Mediapipe_Data\Draw\126\11.npy
# Mediapipe_Data\Draw\126\12.npy
# Mediapipe_Data\Draw\126\13.npy
# Mediapipe_Data\Draw\126\14.npy
# Mediapipe_Data\Draw\127\0.npy
# Mediapipe_Data\Draw\127\1.npy
# Mediapipe_Data\Draw\127\2.npy
# Mediapipe_Data\Draw\127\3.npy
# Mediapipe_Data\Draw\127\4.npy
# Mediapipe_Data\Draw\127\5.npy
# Mediapipe_Data\Draw\127\6.npy
# Mediapipe_Data\Draw\127\7.npy
# Mediapipe_Data\Draw\127\8.npy
# Mediapipe_Data\Draw\127\9.npy
# Mediapipe_Data\Draw\127\10.npy
# Mediapipe_Data\Draw\127\11.npy
# Mediapipe_Data\Draw\127\12.npy
# Mediapipe_Data\Draw\127\13.npy
# Mediapipe_Data\Draw\127\14.npy
# Mediapipe_Data\Draw\128\0.npy
# Mediapipe_Data\Draw\128\1.npy
# Mediapipe_Data\Draw\128\2.npy
# Mediapipe_Data\Draw\128\3.npy
# Mediapipe_Data\Draw\128\4.npy
# Mediapipe_Data\Draw\128\5.npy
# Mediapipe_Data\Draw\128\6.npy
# Mediapipe_Data\Draw\128\7.npy
# Mediapipe_Data\Draw\128\8.npy
# Mediapipe_Data\Draw\128\9.npy
# Mediapipe_Data\Draw\128\10.npy
# Mediapipe_Data\Draw\128\11.npy
# Mediapipe_Data\Draw\128\12.npy
# Mediapipe_Data\Draw\128\13.npy
# Mediapipe_Data\Draw\128\14.npy
# Mediapipe_Data\Draw\129\0.npy
# Mediapipe_Data\Draw\129\1.npy
# Mediapipe_Data\Draw\129\2.npy
# Mediapipe_Data\Draw\129\3.npy
# Mediapipe_Data\Draw\129\4.npy
# Mediapipe_Data\Draw\129\5.npy
# Mediapipe_Data\Draw\129\6.npy
# Mediapipe_Data\Draw\129\7.npy
# Mediapipe_Data\Draw\129\8.npy
# Mediapipe_Data\Draw\129\9.npy
# Mediapipe_Data\Draw\129\10.npy
# Mediapipe_Data\Draw\129\11.npy
# Mediapipe_Data\Draw\129\12.npy
# Mediapipe_Data\Draw\129\13.npy
# Mediapipe_Data\Draw\129\14.npy

# %%
len(sequences)
# Out:
# 260

# %%
len(sequences[0][0])
# Out:
# 63

# %%
np.array(sequences).shape
# Out:
# (260, 15, 63)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.05)
#
# NameError: name 'X' is not defined

# %%
X = np.array(sequences)
X.shape
# Out:
# (260, 15, 63)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20)

# %%
y_test.shape
# Out:
# (52, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64,return_sequences=True, activation='relu', input_shape=(15,63)))
model.add(LSTM(128,return_sequences=True, activation='relu'))
model.add(LSTM(64,return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
model.fit(X_train,y_train,epochs=250,callbacks=[tb_callback])
# Out:
# Epoch 1/250
# 7/7 [==============================] - 9s 30ms/step - loss: 0.6839 - categorical_accuracy: 0.5577
# Epoch 2/250
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5794 - categorical_accuracy: 0.7981
# Epoch 3/250
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4580 - categorical_accuracy: 0.8558
# Epoch 4/250
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3249 - categorical_accuracy: 0.9375
# Epoch 5/250
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2633 - categorical_accuracy: 0.9135
# Epoch 6/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1165 - categorical_accuracy: 0.9663
# Epoch 7/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0290 - categorical_accuracy: 0.9856
# Epoch 8/250
# 7/7 [==============================] - 0s 26ms/step - loss: 2.7705 - categorical_accuracy: 0.8413
# Epoch 9/250
# 7/7 [==============================] - 0s 25ms/step - loss: 0.9566 - categorical_accuracy: 0.5962
# Epoch 10/250
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4841 - categorical_accuracy: 0.8846
# Epoch 11/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4574 - categorical_accuracy: 0.9663
# Epoch 12/250
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2907 - categorical_accuracy: 0.9712
# Epoch 13/250
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1277 - categorical_accuracy: 0.9856
# Epoch 14/250
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0123 - categorical_accuracy: 0.9952
# Epoch 15/250
# 7/7 [==============================] - 0s 26ms/step - loss: 5.4340e-04 - categorical_accuracy: 1.0000
# Epoch 16/250
# 7/7 [==============================] - 0s 25ms/step - loss: 1.3064e-04 - categorical_accuracy: 1.0000
# Epoch 17/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 18/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 19/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 20/250
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 21/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 22/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 23/250
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 24/250
# 3/7 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model.fit(X_train,y_train,epochs=250,callbacks=[tb_callback])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
 res = model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
y_test.shape
# Out:
# (52, 2)

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'Active'

# %%
model.save('actions1.h5')

# %%
model.load_weights('actions.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
yhat = model.predict(X_test)
yhat = np.argmax(yhat, axis=1).tolist()
ytrue = np.argmax(y_test,axis=1).tolist()
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'Active'

# %%
res[0][np.argmax(res[0])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 res[0][np.argmax(res[0])]
#
# IndexError: invalid index to scalar variable.

# %%
multilabel_confusion_matrix(ytrue,yhat)
# Out:
# array([[[29,  0],
#         [ 0, 23]],
#
#        [[23,  0],
#         [ 0, 29]]], dtype=int64)

# %%
accuracy_score(ytrue,yhat)
# Out:
# 1.0

# %%
#Testing in Real Time
sequence = []
sentence = []
threshold = 0.9 #90% 
res = model.predict(X_test)
vidcap = cv2.VideoCapture(0)
with mp_hands.Hands(min_detection_confidence=0.8,min_tracking_confidence=0.5,max_num_hands=1) as hands:
    while vidcap.isOpened():
        ret,frame = vidcap.read()
        image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)#OpenCV works in BlueGreenRed format 
                                                     #but Mediapipe works in RedGreenBlue format
        image.flags.writeable = False #setting flags to prevent copying the image
        results = hands.process(image) #detection
        image.flags.writeable = True #setting it back
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) #changing back
        #print(results) #output all the landmarks 
        if results.multi_hand_landmarks:
            draw_hlandmarks(frame,results) #rendering
        
        #predictions
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-50:]
        
        if len(sequence) == 50:
            res = model.predict(np.expand_dims(sequence,axis=0))[0] #get the result
            print(actions[np.argmax(res)]) 
            
            if res[np.argmax(res)] > threshold:
                if len(sentence) > 0:
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

        if len(sentence) > 5:
            sentence = sentence[-5:0]
        cv2.rectangle(frame,(0,0),(640,40),(245,117,16),-1)
        cv2.putText(frame,' '.join(sentence),(3,30),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,255),2,cv2.LINE_AA)
        
        cv2.imshow('Hand Tracking',frame)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    vidcap.release()
    cv2.destroyAllWindows()
# Out:
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 1s 912ms/step
# Draw
# 1/1 [==============================] - 0s 43ms/step
# Draw
# 1/1 [==============================] - 0s 38ms/step
# Draw
# 1/1 [==============================] - 0s 40ms/step
# Draw
# 1/1 [==============================] - 0s 32ms/step
# Draw
# 1/1 [==============================] - 0s 34ms/step
# Draw
# 1/1 [==============================] - 0s 38ms/step
# Draw
# 1/1 [==============================] - 0s 29ms/step
# Draw
# 1/1 [==============================] - 0s 32ms/step
# Draw
# 1/1 [==============================] - 0s 36ms/step
# Draw
# 1/1 [==============================] - 0s 36ms/step
# Draw
# 1/1 [==============================] - 0s 30ms/step
# Draw
# 1/1 [==============================] - 0s 30ms/step
# Draw
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 35ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 35ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 33ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 37ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Draw
# 1/1 [==============================] - 0s 34ms/step
# Draw
# 1/1 [==============================] - 0s 30ms/step
# Draw
# 1/1 [==============================] - 0s 28ms/step
# Draw
# 1/1 [==============================] - 0s 32ms/step
# Draw
# 1/1 [==============================] - 0s 33ms/step
# Draw
# 1/1 [==============================] - 0s 29ms/step
# Draw
# 1/1 [==============================] - 0s 33ms/step
# Draw
# 1/1 [==============================] - 0s 27ms/step
# Draw
# 1/1 [==============================] - 0s 27ms/step
# Draw
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 27ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 27ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 37ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 27ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 33ms/step
# Active
# 1/1 [==============================] - 0s 46ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 27ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 27ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 33ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 26ms/step
# Active
# 1/1 [==============================] - 0s 32ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 27ms/step
# Active
# 1/1 [==============================] - 0s 31ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 34ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 30ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 35ms/step
# Active
# 1/1 [==============================] - 0s 33ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 29ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Active
# 1/1 [==============================] - 0s 28ms/step
# Draw
# 1/1 [==============================] - 0s 43ms/step
# Draw
# 1/1 [==============================] - 0s 28ms/step
# Draw
# 1/1 [==============================] - 0s 28ms/step
# Draw
# 1/1 [==============================] - 0s 28ms/step
# Draw
# 1/1 [==============================] - 0s 110ms/step
# Draw
# 1/1 [==============================] - 0s 31ms/step
# Draw
# 1/1 [==============================] - 0s 30ms/step
# Draw

# %%
vidcap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vidcap.release()
#       2 cv2.destroyAllWindows()
#
# NameError: name 'vidcap' is not defined

# %%
#Testing in Real Time
sequence = []
result = "" 
threshold = 0.40 #90% 
res = model.predict(X_test)
vidcap = cv2.VideoCapture(0)
with mp_hands.Hands(min_detection_confidence=0.8,min_tracking_confidence=0.5,max_num_hands=1) as hands:
    while vidcap.isOpened():
        ret,frame = vidcap.read()
        image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)#OpenCV works in BlueGreenRed format 
                                                     #but Mediapipe works in RedGreenBlue format
        image.flags.writeable = False #setting flags to prevent copying the image
        results = hands.process(image) #detection
        image.flags.writeable = True #setting it back
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) #changing back
        #print(results) #output all the landmarks 
        if results.multi_hand_landmarks:
            draw_hlandmarks(frame,results) #rendering
        
        #predictions
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-50:]
        
        if len(sequence) == 50:
            res = model.predict(np.expand_dims(sequence,axis=0))[0] #get the result
            if res[np.argmax(res)] > threshold:
                result = actions[np.argmax(res)]
        cv2.rectangle(frame,(0,0),(640,40),(245,117,16),-1)
        cv2.putText(frame,result,(3,30),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,255),2,cv2.LINE_AA)
        
        cv2.imshow('Hand Tracking',frame)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    vidcap.release()
    cv2.destroyAllWindows()
# Out:
# 2/2 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
